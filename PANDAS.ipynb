# %%
import pandas as pd

# %% [markdown]
# 1 Dimension

# %%
s=pd.Series([1, 3, 5, 7, 9])
print(s)
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %% [markdown]
# 2 dimension

# %%
data={
    "Name":["Ali","Hussain","Hassan"],
    "Age" :[22,24,25]
}
df =pd.DataFrame(data)
print(df)
# Out:
#       Name  Age
# 0      Ali   22
# 1  Hussain   24
# 2   Hassan   25

# %% [markdown]
# importing files

# %%
df=pd.read_csv("AI_USAGE.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1728574617.py in <cell line: 0>()
# ----> 1 df=pd.read_csv("AI_USAGE.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
df.to_csv("AI_USAGE.csv")

# %% [markdown]
# Shapes

# %%
df.head()
# Out:
#       Name  Age
# 0      Ali   22
# 1  Hussain   24
# 2   Hassan   25

# %%
df.tail()
# Out:
#       Name  Age
# 0      Ali   22
# 1  Hussain   24
# 2   Hassan   25

# %%
df.shape
# Out:
# (3, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   23.666667
# std     1.527525
# min    22.000000
# 25%    23.000000
# 50%    24.000000
# 75%    24.500000
# max    25.000000

# %%
df[["device","prompt_length"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-524489870.py in <cell line: 0>()
# ----> 1 df[["device","prompt_length"]]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %% [markdown]
# 2️⃣ Select ROWS using iloc (index-based)

# %%
df.iloc[0:3]

# %% [markdown]
# 3️⃣ Select ROWS using loc (label-based)

# %%
df.loc[0:3]

# %% [markdown]
# 4️⃣ Boolean Filtering

# %%
df[df["prompt_length"]>10]

# %% [markdown]
# Adding, Updating, Deleting Columns

# %%
cities = ["Lahore", "Islamabad", "Karachi"]
df["City"] = [cities[i % len(cities)] for i in range(len(df))]
print(df.head())

# %% [markdown]
# deleting column

# %%
df.drop("City",axis=1,inplace=True)

# %% [markdown]
# Sorting

# %%
df.sort_values("Prompt")

# %%
df.sort_values("Prompt",ascending=True)

# %%
df.isnull().sum()
# Out:
# Name    0
# Age     0
# dtype: int64

# %%
display(df.isnull().sum())

# %%
df.dropna()
# Out:
#       Name  Age
# 0      Ali   22
# 1  Hussain   24
# 2   Hassan   25
